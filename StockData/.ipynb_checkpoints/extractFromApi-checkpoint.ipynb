# %% [markdown]
# # Extracting the European Stocks data
#
# ### Below python code extracts the stocks data from yfinance API against provided stock codes from CSV file
#
# #### Author: Rohan Indrajeet Jadhav [x20169043@studemt.ncirl.ie]
#
# #### Contents
#
# 1. Import the CSV file for reading list of stocks and their countries
# 2. Extract the data for those stocks from yfinance api
# 3. pre-process the data before loading into MongoDB
# 4. Load the data into MongoDB
#     a. DB name: covidStockAnalysis
#     b. Collection Name: stocksData

# %%
# Importing the libraries required 

from pprint import pprint
import pandas as pd
import yfinance as yf
import datetime 
import pandas as pd
from pymongo import MongoClient
from pandas_datareader import data as pdr
import csv
import os

# %%
# Setting up the dates for extracting the stock data within given range
# Targeting for time frame from where COVID started and till now.

start = datetime.datetime(2019,12,1) 
end = datetime.datetime.now() 

dateTimeVar = "Stock data will be extracted from {0} till {1}".format(start,end)
print(dateTimeVar)
# Out:
# Stock data will be extracted from 2019-12-01 00:00:00 till 2021-04-23 22:22:18.882845

# %% [markdown]
# ### Reading the CSV file names StocksExchange.csv to extract list of stocks and country name
#
# ![alt text](stockformat.PNG "Title")

# %%
# Reading the CSV file names StocksExchange.csv for stock codes and their countries

inputStocks = []
with open('StocksExchange.csv') as stockDetails:
    csv_reader = csv.reader(stockDetails, delimiter=',')
    headerChecker = 0
    for row in csv_reader:
        if(headerChecker == 0 ):
            headerChecker += 1
            continue
               
        else:
            inputStocks.append(row) 

print(inputStocks)
# Out:
# [['SOFIX', 'Austria'], ['BGBX40', 'Austria'], ['BGREIT', 'Austria'], ['BGTR30', 'Austria'], ['CGIX', 'Austria'], ['HZVG', 'Belgium'], ['IGH', 'Belgium'], ['DLKV', 'Belgium'], ['ATPL', 'Belgium'], ['DOY', 'Ireland'], ['A5G', 'Ireland'], ['DD7E', 'Ireland'], ['DD7D', 'Ireland'], ['BIRG', 'Ireland'], ['C5H', 'Ireland'], ['DD8A', 'Ireland'], ['DD8B', 'Ireland'], ['CRG', 'Ireland'], ['DHG', 'Ireland'], ['DLE', 'Ireland'], ['GUI1', 'Ireland'], ['DQ7A', 'Ireland'], ['IR5B', 'Ireland'], ['IRES', 'Ireland'], ['ORPH', 'Ireland'], ['ENI', 'Italy'], ['ENEL', 'Italy'], ['ISP', 'Italy'], ['UCG', 'Italy'], ['TS', 'Italy'], ['ATL', 'Italy'], ['RDSA', 'Netherland'], ['UNA', 'Netherland'], ['ASML', 'Netherland'], ['HEIA', 'Netherland'], ['REL', 'Netherland'], ['ITX', 'Spain'], ['SAN', 'Spain'], ['IBE', 'Spain'], ['BBVA', 'Spain'], ['TEF', 'Spain'], ['AMS', 'Spain'], ['MTS', 'Spain'], ['IEKG', 'Romania'], ['POSR', 'Romania'], ['MELR', 'Romania'], ['ZVTG', 'Romania'], ['LKPG', 'Romania'], ['DAX30', 'Germany'], ['DAX', 'Germany'], ['MOEX', 'Germany'], ['TSX', 'Germany'], ['SAP', 'Germany'], ['BMW', 'Germany'], ['ADS', 'Germany'], ['BAYN', 'Germany'], ['ADSGN', 'Germany'], ['ALVG', 'Germany'], ['BASFN', 'Germany'], ['BAYGN', 'Germany'], ['BEIG', 'Germany'], ['1COV', 'Germany'], ['DAIGn', 'Germany'], ['DHER', 'Germany'], ['BMWG', 'Germany'], ['PLNGBP', 'Poland'], ['PLNEUR', 'Poland'], ['PLNUSD', 'Poland'], ['BET', 'Romania'], ['BET-TR', 'Romania'], ['BET-FI', 'Romania'], ['ROTX', 'Romania'], ['SAF', 'France'], ['RMS', 'France'], ['RNO', 'France'], ['SW', 'France'], ['SNY', 'European'], ['RDEIY', 'European'], ['BTI', 'European'], ['SAP', 'European'], ['UL', 'European'], ['RHHBY', 'European'], ['NVS', 'European'], ['NVO', 'European'], ['VEA', 'European']]

# %%
#Testing the MongoDB connection before loading the extracted data 
# DB name used : "covidStockAnalysis"
#Collection used : "stocksData"

try:
    client = MongoClient()
    print(client)
    db = client.stockDB
    print(db)
    collection = db.stocksData
except:
    print("MongoDB connection Issue please check details: ")
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')

# %% [markdown]
# ### Extracts the stock data against list of stock passed from csv file and formats it to load into MongoDB

# %%
# This command will read the stock names extracted from CSV above
# Extract the stock data from yfinance API for stock codes 
# Extracted code will get reformed into dictionary in order to load it to mongoDB in documents
# This again creates csv file whose stock data is not available right now.

totalNoOfStocks = 0
dbName = "covidStockAnalysis"
collectionName = 'stocksData'

#Remove the CSV file before creating it

try:
    os.remove('stocksListDataNotAvailable.csv')
except:
    print("Unable to remove the file")

#Dropping the collection before loading data

try:
    db[collectionName].drop();
    print('Collection dropped successfully!!')
except:
    print("Error in dropping the collection: {0} under {1} ".format(collectionName,dbName))

for stock in inputStocks:
    
    stockCode = stock[0]
    countryName = stock[1]
    print(stockCode)
    
    
    try:
        dfStockValues = yf.download(stockCode,start=start, end=end )
    except ValueError as ver:
        print("Stock Data is not available for: ", stockCode)
        
    if dfStockValues.empty:
        
        print("Stock Data is not available for: ", stockCode)
        
        try:
            with open('stocksListDataNotAvailable.csv', mode='a') as stockData:
                stockWriter = csv.writer(stockData, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                stockWriter.writerow([stock, countryName])
        except OSError:
            print("Error in reading file")
            
    else:
        
        records_in_df = len(dfStockValues.index)
        
# Adds 2 columns named stockName and CoountryName extracted from CSV file provided. yfinance api does not give the stock country name

        dfStockValues.reset_index(level=0, inplace=True)
        dfStockValues['stockName'] = stockCode
        dfStockValues['countryName'] = countryName
        after_reset = dfStockValues.reset_index()

# Checks MongoDB connection if working fine inserts the formatted record
        try:
            client = MongoClient()
            print(client)
            db = client.stockDB
            print(db)
            collection = db.stockdata
        except:
            print("MongoDB connection error")
    
        after_reset.index = after_reset.index.map(str)
        temp_dict = after_reset.transpose().to_dict()
        
        for oneOff in temp_dict.values():
            db.stocksData.insert_one(oneOff)
            
        totalNoOfStocks = totalNoOfStocks + records_in_df

print("Total records: ", totalNoOfStocks)
# Out:
# Collection dropped successfully!!
# SOFIX
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SOFIX: No data found, symbol may be delisted
# Stock Data is not available for:  SOFIX
# BGBX40
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BGBX40: No data found, symbol may be delisted
# Stock Data is not available for:  BGBX40
# BGREIT
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BGREIT: No data found, symbol may be delisted
# Stock Data is not available for:  BGREIT
# BGTR30
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BGTR30: No data found, symbol may be delisted
# Stock Data is not available for:  BGTR30
# CGIX
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# HZVG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HZVG: No data found, symbol may be delisted
# Stock Data is not available for:  HZVG
# IGH
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# DLKV
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DLKV: No data found, symbol may be delisted
# Stock Data is not available for:  DLKV
# ATPL
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# DOY
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DOY: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  DOY
# A5G
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - A5G: No data found, symbol may be delisted
# Stock Data is not available for:  A5G
# DD7E
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DD7E: No data found, symbol may be delisted
# Stock Data is not available for:  DD7E
# DD7D
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DD7D: No data found, symbol may be delisted
# Stock Data is not available for:  DD7D
# BIRG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BIRG: No data found, symbol may be delisted
# Stock Data is not available for:  BIRG
# C5H
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - C5H: No data found, symbol may be delisted
# Stock Data is not available for:  C5H
# DD8A
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DD8A: No data found, symbol may be delisted
# Stock Data is not available for:  DD8A
# DD8B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DD8B: No data found, symbol may be delisted
# Stock Data is not available for:  DD8B
# CRG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CRG: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  CRG
# DHG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DHG: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  DHG
# DLE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DLE: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  DLE
# GUI1
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GUI1: No data found, symbol may be delisted
# Stock Data is not available for:  GUI1
# DQ7A
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DQ7A: No data found, symbol may be delisted
# Stock Data is not available for:  DQ7A
# IR5B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - IR5B: No data found, symbol may be delisted
# Stock Data is not available for:  IR5B
# IRES
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - IRES: No data found, symbol may be delisted
# Stock Data is not available for:  IRES
# ORPH
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# ENI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ENI: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  ENI
# ENEL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ENEL: No data found, symbol may be delisted
# Stock Data is not available for:  ENEL
# ISP
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# UCG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - UCG: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  UCG
# TS
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# ATL
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# RDSA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RDSA: No data found, symbol may be delisted
# Stock Data is not available for:  RDSA
# UNA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - UNA: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  UNA
# ASML
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# HEIA
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HEIA: No data found, symbol may be delisted
# Stock Data is not available for:  HEIA
# REL
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - REL: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  REL
# ITX
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ITX: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  ITX
# SAN
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# IBE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - IBE: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  IBE
# BBVA
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# TEF
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# AMS
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# MTS
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MTS: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  MTS
# IEKG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - IEKG: No data found, symbol may be delisted
# Stock Data is not available for:  IEKG
# POSR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - POSR: No data found, symbol may be delisted
# Stock Data is not available for:  POSR
# MELR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MELR: No data found, symbol may be delisted
# Stock Data is not available for:  MELR
# ZVTG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZVTG: No data found, symbol may be delisted
# Stock Data is not available for:  ZVTG
# LKPG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LKPG: No data found, symbol may be delisted
# Stock Data is not available for:  LKPG
# DAX30
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DAX30: No data found, symbol may be delisted
# Stock Data is not available for:  DAX30
# DAX
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# MOEX
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MOEX: No data found, symbol may be delisted
# Stock Data is not available for:  MOEX
# TSX
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TSX: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  TSX
# SAP
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# BMW
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BMW: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  BMW
# ADS
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# BAYN
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# ADSGN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADSGN: No data found, symbol may be delisted
# Stock Data is not available for:  ADSGN
# ALVG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALVG: No data found, symbol may be delisted
# Stock Data is not available for:  ALVG
# BASFN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BASFN: No data found, symbol may be delisted
# Stock Data is not available for:  BASFN
# BAYGN
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAYGN: No data found, symbol may be delisted
# Stock Data is not available for:  BAYGN
# BEIG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BEIG: No data found, symbol may be delisted
# Stock Data is not available for:  BEIG
# 1COV
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - 1COV: No data found, symbol may be delisted
# Stock Data is not available for:  1COV
# DAIGn
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DAIGN: No data found, symbol may be delisted
# Stock Data is not available for:  DAIGn
# DHER
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DHER: No data found, symbol may be delisted
# Stock Data is not available for:  DHER
# BMWG
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BMWG: No data found, symbol may be delisted
# Stock Data is not available for:  BMWG
# PLNGBP
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PLNGBP: No data found, symbol may be delisted
# Stock Data is not available for:  PLNGBP
# PLNEUR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PLNEUR: No data found, symbol may be delisted
# Stock Data is not available for:  PLNEUR
# PLNUSD
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PLNUSD: No data found, symbol may be delisted
# Stock Data is not available for:  PLNUSD
# BET
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# BET-TR
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BET-TR: No data found, symbol may be delisted
# Stock Data is not available for:  BET-TR
# BET-FI
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BET-FI: No data found, symbol may be delisted
# Stock Data is not available for:  BET-FI
# ROTX
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ROTX: No data found, symbol may be delisted
# Stock Data is not available for:  ROTX
# SAF
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# RMS
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RMS: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  RMS
# RNO
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RNO: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  RNO
# SW
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SW: No data found for this date range, symbol may be delisted
# Stock Data is not available for:  SW
# SNY
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# RDEIY
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# BTI
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# SAP
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# UL
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# RHHBY
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# NVS
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# NVO
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# VEA
# [*********************100%***********************]  1 of 1 completed
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'stockDB')
# Total records:  8907

# %%
# This is calling the next notbook which will read the loaded MongoDb data

# %run ./read_from_mongoDB.ipynb
